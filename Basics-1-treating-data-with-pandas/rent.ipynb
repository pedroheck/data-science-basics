# %% [markdown]
# ### Importing the Data

# %%
import pandas as pd

df = pd.read_csv('data/rent.csv', sep=';')
df.head(10)
# Out:
#                 Type         District  Rooms  Vacancies  Suites  Area  \
# 0        Kitchenette       Copacabana      1          0       0    40
# 1              House  Jardim Botânico      2          0       1   100
# 2     Commercial Set  Barra da Tijuca      0          4       0   150
# 3          Apartment           Centro      1          0       0    15
# 4          Apartment     Higienópolis      1          0       0    48
# 5          Apartment     Vista Alegre      3          1       0    70
# 6          Apartment         Cachambi      2          0       0    50
# 7  Condominuim House  Barra da Tijuca      5          4       5   750
# 8  Condominuim House            Ramos      2          2       0    65
# 9     Commercial Set           Centro      0          3       0   695
#
#      Value  Condominium   Taxes
# 0   1700.0        500.0    60.0
# 1   7000.0          NaN     NaN
# 2   5200.0       4020.0  1111.0
# 3    800.0        390.0    20.0
# 4    800.0        230.0     NaN
# 5   1200.0          NaN     NaN
# 6   1300.0        301.0    17.0
# 7  22000.0          NaN     NaN
# 8   1000.0          NaN     NaN
# 9  35000.0      19193.0  3030.0

# %% [markdown]
# ### How to read data in different formats?
#
# CSV -> pd.read_csv()
#
# JSON -> pd.read_json()
#
# TXT -> pd.read_table()
#
# EXCEL (.xlsx) -> pd.read_excel()
#
# HTML -> pd.read_html()

# %% [markdown]
# ## Getting to know more about our data

# %%
data_types = pd.DataFrame(df.dtypes, columns=['Data Types']) # Data types

# %%
data_types.columns.name = 'Variables'
data_types
# Out:
# Variables   Data Types
# Type            object
# District        object
# Rooms            int64
# Vacancies        int64
# Suites           int64
# Area             int64
# Value          float64
# Condominium    float64
# Taxes          float64

# %%
# Seeing how many rows and columns
df.shape
# Out:
# (32960, 9)

# %% [markdown]
# Let's now create a pandas series containing all the property types

# %%
property_types = df['Type']
property_types
# Out:
# 0           Kitchenette
# 1                 House
# 2        Commercial Set
# 3             Apartment
# 4             Apartment
#               ...
# 32955       Kitchenette
# 32956         Apartment
# 32957         Apartment
# 32958         Apartment
# 32959    Commercial Set
# Name: Type, Length: 32960, dtype: object

# %% [markdown]
# ### Removing **duplicate values**

# %%
# Now let's remove the repeated values
property_types.drop_duplicates(inplace=True) # inplace=True means that the changes will be made in the original variable
property_types
# Out:
# 0                             Kitchenette
# 1                                   House
# 2                          Commercial Set
# 3                               Apartment
# 7                       Condominuim House
# 16                         Whole Building
# 17                                   Flat
# 29                             Store/Hall
# 80                         Shed/Warehouse
# 83                       Commercial House
# 117                         Village House
# 159                         Standard Land
# 207                                Garage
# 347                                  Loft
# 589      Shopping Store/Commercial Center
# 2157                                 Farm
# 3354                Allotment/Condominium
# 4379                               Grange
# 4721                          Inn/Cottage
# 6983                               Studio
# 9687                                Hotel
# 23614                            Industry
# Name: Type, dtype: object

# %% [markdown]
# Now let's correct the indexes

# %%
property_types = pd.DataFrame(property_types) # Converting to a dataframe

property_types.index = range(property_types.shape[0]) # Changing the index
# Can also be property_types.index = range(len(property_types))
property_types
# Out:
#                                 Type
# 0                        Kitchenette
# 1                              House
# 2                     Commercial Set
# 3                          Apartment
# 4                  Condominuim House
# 5                     Whole Building
# 6                               Flat
# 7                         Store/Hall
# 8                     Shed/Warehouse
# 9                   Commercial House
# 10                     Village House
# 11                     Standard Land
# 12                            Garage
# 13                              Loft
# 14  Shopping Store/Commercial Center
# 15                              Farm
# 16             Allotment/Condominium
# 17                            Grange
# 18                       Inn/Cottage
# 19                            Studio
# 20                             Hotel
# 21                          Industry

# %%
property_types.columns.name = 'Id'
property_types
# Out:
# Id                              Type
# 0                        Kitchenette
# 1                              House
# 2                     Commercial Set
# 3                          Apartment
# 4                  Condominuim House
# 5                     Whole Building
# 6                               Flat
# 7                         Store/Hall
# 8                     Shed/Warehouse
# 9                   Commercial House
# 10                     Village House
# 11                     Standard Land
# 12                            Garage
# 13                              Loft
# 14  Shopping Store/Commercial Center
# 15                              Farm
# 16             Allotment/Condominium
# 17                            Grange
# 18                       Inn/Cottage
# 19                            Studio
# 20                             Hotel
# 21                          Industry

# %% [markdown]
# ## Filtering data

# %% [markdown]
# If we only want to deal with residential properties, it may be best for us to **create a new dataset** containing only the desired properties.
#
# For that, let's start by creating a list containing only the residential types that we're looking for

# %%
residential = ['Kitchenette', 'House', 'Apartment', 'Condominium House', 'Village House']

# %% [markdown]
# Now we'll create a list that tells us whether each row represents a residential property (True) or not (False)

# %%
selection = df['Type'].isin(residential)
selection
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Type, Length: 32960, dtype: bool

# %% [markdown]
# We can than use this to extrude only the True values from our original dataframe

# %%
residential_df = df[selection]
residential_df
# Out:
#               Type              District  Rooms  Vacancies  Suites  Area  \
# 0      Kitchenette            Copacabana      1          0       0    40
# 1            House       Jardim Botânico      2          0       1   100
# 3        Apartment                Centro      1          0       0    15
# 4        Apartment          Higienópolis      1          0       0    48
# 5        Apartment          Vista Alegre      3          1       0    70
# ...            ...                   ...    ...        ...     ...   ...
# 32953    Apartment                 Méier      2          0       0    70
# 32955  Kitchenette                Centro      0          0       0    27
# 32956    Apartment           Jacarepaguá      3          1       2    78
# 32957    Apartment  São Francisco Xavier      2          1       0    48
# 32958    Apartment                Leblon      2          0       0    70
#
#         Value  Condominium  Taxes
# 0      1700.0        500.0   60.0
# 1      7000.0          NaN    NaN
# 3       800.0        390.0   20.0
# 4       800.0        230.0    NaN
# 5      1200.0          NaN    NaN
# ...       ...          ...    ...
# 32953   900.0        490.0   48.0
# 32955   800.0        350.0   25.0
# 32956  1800.0        800.0   40.0
# 32957  1400.0        509.0   37.0
# 32958  3000.0        760.0    NaN
#
# [21584 rows x 9 columns]

# %% [markdown]
# It's that simple! But the indexes are all wrong now... which is okay, because we've done that before

# %%
residential_df.index = range(residential_df.shape[0])
residential_df
# Out:
#               Type              District  Rooms  Vacancies  Suites  Area  \
# 0      Kitchenette            Copacabana      1          0       0    40
# 1            House       Jardim Botânico      2          0       1   100
# 2        Apartment                Centro      1          0       0    15
# 3        Apartment          Higienópolis      1          0       0    48
# 4        Apartment          Vista Alegre      3          1       0    70
# ...            ...                   ...    ...        ...     ...   ...
# 21579    Apartment                 Méier      2          0       0    70
# 21580  Kitchenette                Centro      0          0       0    27
# 21581    Apartment           Jacarepaguá      3          1       2    78
# 21582    Apartment  São Francisco Xavier      2          1       0    48
# 21583    Apartment                Leblon      2          0       0    70
#
#         Value  Condominium  Taxes
# 0      1700.0        500.0   60.0
# 1      7000.0          NaN    NaN
# 2       800.0        390.0   20.0
# 3       800.0        230.0    NaN
# 4      1200.0          NaN    NaN
# ...       ...          ...    ...
# 21579   900.0        490.0   48.0
# 21580   800.0        350.0   25.0
# 21581  1800.0        800.0   40.0
# 21582  1400.0        509.0   37.0
# 21583  3000.0        760.0    NaN
#
# [21584 rows x 9 columns]

# %% [markdown]
# ### Exporting the new dataframe

# %%
residential_df.to_csv('data/residential_rent.csv', sep=';')

# %% [markdown]
# That was easy! Let's just check if everything is sound

# %%
residential_df_2 = pd.read_csv('data/residential_rent.csv', sep=';')
residential_df_2
# Out:
#        Unnamed: 0         Type              District  Rooms  Vacancies  \
# 0               0  Kitchenette            Copacabana      1          0
# 1               1        House       Jardim Botânico      2          0
# 2               2    Apartment                Centro      1          0
# 3               3    Apartment          Higienópolis      1          0
# 4               4    Apartment          Vista Alegre      3          1
# ...           ...          ...                   ...    ...        ...
# 21579       21579    Apartment                 Méier      2          0
# 21580       21580  Kitchenette                Centro      0          0
# 21581       21581    Apartment           Jacarepaguá      3          1
# 21582       21582    Apartment  São Francisco Xavier      2          1
# 21583       21583    Apartment                Leblon      2          0
#
#        Suites  Area   Value  Condominium  Taxes
# 0           0    40  1700.0        500.0   60.0
# 1           1   100  7000.0          NaN    NaN
# 2           0    15   800.0        390.0   20.0
# 3           0    48   800.0        230.0    NaN
# 4           0    70  1200.0          NaN    NaN
# ...       ...   ...     ...          ...    ...
# 21579       0    70   900.0        490.0   48.0
# 21580       0    27   800.0        350.0   25.0
# 21581       2    78  1800.0        800.0   40.0
# 21582       0    48  1400.0        509.0   37.0
# 21583       0    70  3000.0        760.0    NaN
#
# [21584 rows x 10 columns]

# %% [markdown]
# Oopsie! It thinks that our index is a column of its own! Let's fix this

# %%
residential_df.to_csv('data/residential_rent.csv', sep=';', index=False) # We should change the index parameter to False!

# %%
residential_df_2 = pd.read_csv('data/residential_rent.csv', sep=';')
residential_df_2
# Out:
#               Type              District  Rooms  Vacancies  Suites  Area  \
# 0      Kitchenette            Copacabana      1          0       0    40
# 1            House       Jardim Botânico      2          0       1   100
# 2        Apartment                Centro      1          0       0    15
# 3        Apartment          Higienópolis      1          0       0    48
# 4        Apartment          Vista Alegre      3          1       0    70
# ...            ...                   ...    ...        ...     ...   ...
# 21579    Apartment                 Méier      2          0       0    70
# 21580  Kitchenette                Centro      0          0       0    27
# 21581    Apartment           Jacarepaguá      3          1       2    78
# 21582    Apartment  São Francisco Xavier      2          1       0    48
# 21583    Apartment                Leblon      2          0       0    70
#
#         Value  Condominium  Taxes
# 0      1700.0        500.0   60.0
# 1      7000.0          NaN    NaN
# 2       800.0        390.0   20.0
# 3       800.0        230.0    NaN
# 4      1200.0          NaN    NaN
# ...       ...          ...    ...
# 21579   900.0        490.0   48.0
# 21580   800.0        350.0   25.0
# 21581  1800.0        800.0   40.0
# 21582  1400.0        509.0   37.0
# 21583  3000.0        760.0    NaN
#
# [21584 rows x 9 columns]

# %% [markdown]
# Now it looks right!
